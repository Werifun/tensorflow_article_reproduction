# %%
import tensorflow as tf
from tensorflow.examples.tutorials.mnist import input_data

# %%
# 数据集
mnist = input_data.read_data_sets("MNIST_data", one_hot=True)

# 每个批次的大小
batch_size = 100
# 计算你一共有多少个批次
n_batch = mnist.train.num_examples // batch_size

# 定义两个placeholder,作为输入和输出
x = tf.placeholder(tf.float32, [None, 784])
y = tf.placeholder(tf.float32, [None, 10])


# 创建一个简单的神经网络
W = tf.Variable(tf.zeros([784, 10]))
b = tf.Variable(tf.zeros([10]))

prediction = tf.nn.softmax(tf.matmul(x,W)+b)

# 二次代价函数
loss = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits(labels=y,logits=prediction))
# 使用梯度下降
train_step = tf.train.GradientDescentOptimizer(0.2).minimize(loss)

# 初始化变量
init = tf.global_variables_initializer()

# 结果存放在一个bool型列表中
correct_prediction = tf.equal(tf.arg_max(y,1), tf.arg_max(prediction, 1))

# 求准确率
accuracy = tf.reduce_mean(tf.cast(correct_prediction, tf.float32))

with tf.Session() as sess:
    sess.run(init)
    for epoch in range(201):
        for batch in range(n_batch):
            batch_x, batch_y = mnist.train.next_batch(batch_size)
            sess.run(train_step, feed_dict={x:batch_x,y:batch_y})
        
        acc = sess.run(accuracy, feed_dict={x:mnist.test.images, y:mnist.test.labels})
        print("Iter {} , Testing Accurancy {}".format(epoch, acc))
# Out:
# Extracting MNIST_data\train-images-idx3-ubyte.gz
# Extracting MNIST_data\train-labels-idx1-ubyte.gz
# Extracting MNIST_data\t10k-images-idx3-ubyte.gz
# Extracting MNIST_data\t10k-labels-idx1-ubyte.gz
# Iter 0 , Testing Accurancy 0.8240000009536743
# Iter 1 , Testing Accurancy 0.8759999871253967
# Iter 2 , Testing Accurancy 0.8996000289916992
# Iter 3 , Testing Accurancy 0.9046000242233276
# Iter 4 , Testing Accurancy 0.9074000120162964
# Iter 5 , Testing Accurancy 0.9093000292778015
# Iter 6 , Testing Accurancy 0.9115999937057495
# Iter 7 , Testing Accurancy 0.9124000072479248
# Iter 8 , Testing Accurancy 0.914900004863739
# Iter 9 , Testing Accurancy 0.9154999852180481
# Iter 10 , Testing Accurancy 0.9171000123023987
# Iter 11 , Testing Accurancy 0.9186999797821045
# Iter 12 , Testing Accurancy 0.9186000227928162
# Iter 13 , Testing Accurancy 0.9190999865531921
# Iter 14 , Testing Accurancy 0.9192000031471252
# Iter 15 , Testing Accurancy 0.9207000136375427
# Iter 16 , Testing Accurancy 0.9204000234603882
# Iter 17 , Testing Accurancy 0.9211999773979187
# Iter 18 , Testing Accurancy 0.9212999939918518
# Iter 19 , Testing Accurancy 0.9215999841690063
# Iter 20 , Testing Accurancy 0.9221000075340271
# Iter 21 , Testing Accurancy 0.9221000075340271
# Iter 22 , Testing Accurancy 0.9218000173568726
# Iter 23 , Testing Accurancy 0.9225999712944031
# Iter 24 , Testing Accurancy 0.9221000075340271
# Iter 25 , Testing Accurancy 0.9229000210762024
# Iter 26 , Testing Accurancy 0.9232000112533569
# Iter 27 , Testing Accurancy 0.9235000014305115
# Iter 28 , Testing Accurancy 0.9239000082015991
# Iter 29 , Testing Accurancy 0.9230999946594238
# Iter 30 , Testing Accurancy 0.9239000082015991
# Iter 31 , Testing Accurancy 0.9240999817848206
# Iter 32 , Testing Accurancy 0.9243000149726868
# Iter 33 , Testing Accurancy 0.9240000247955322
# Iter 34 , Testing Accurancy 0.9240999817848206
# Iter 35 , Testing Accurancy 0.9246000051498413
# Iter 36 , Testing Accurancy 0.9244999885559082
# Iter 37 , Testing Accurancy 0.9254999756813049
# Iter 38 , Testing Accurancy 0.9243000149726868
# Iter 39 , Testing Accurancy 0.9262999892234802
# Iter 40 , Testing Accurancy 0.9253000020980835
# Iter 41 , Testing Accurancy 0.9264000058174133
# Iter 42 , Testing Accurancy 0.9259999990463257
# Iter 43 , Testing Accurancy 0.9261999726295471
# Iter 44 , Testing Accurancy 0.9273999929428101
# Iter 45 , Testing Accurancy 0.9266999959945679
# Iter 46 , Testing Accurancy 0.9269999861717224
# Iter 47 , Testing Accurancy 0.9269000291824341
# Iter 48 , Testing Accurancy 0.927299976348877
# Iter 49 , Testing Accurancy 0.9264000058174133
# Iter 50 , Testing Accurancy 0.926800012588501
# Iter 51 , Testing Accurancy 0.9273999929428101
# Iter 52 , Testing Accurancy 0.9269999861717224
# Iter 53 , Testing Accurancy 0.925599992275238
# Iter 54 , Testing Accurancy 0.9283000230789185
# Iter 55 , Testing Accurancy 0.9265000224113464
# Iter 56 , Testing Accurancy 0.9273999929428101
# Iter 57 , Testing Accurancy 0.9280999898910522
# Iter 58 , Testing Accurancy 0.9275000095367432
# Iter 59 , Testing Accurancy 0.9277999997138977
# Iter 60 , Testing Accurancy 0.9279999732971191
# Iter 61 , Testing Accurancy 0.9273999929428101
# Iter 62 , Testing Accurancy 0.9272000193595886
# Iter 63 , Testing Accurancy 0.9269000291824341
# Iter 64 , Testing Accurancy 0.9279000163078308
# Iter 65 , Testing Accurancy 0.9279000163078308
# Iter 66 , Testing Accurancy 0.9276999831199646
# Iter 67 , Testing Accurancy 0.9291999936103821
# Iter 68 , Testing Accurancy 0.9282000064849854
# Iter 69 , Testing Accurancy 0.9280999898910522
# Iter 70 , Testing Accurancy 0.9283999800682068
# Iter 71 , Testing Accurancy 0.928600013256073
# Iter 72 , Testing Accurancy 0.9291999936103821
# Iter 73 , Testing Accurancy 0.9279999732971191
# Iter 74 , Testing Accurancy 0.9275000095367432
# Iter 75 , Testing Accurancy 0.9289000034332275
# Iter 76 , Testing Accurancy 0.9283000230789185
# Iter 77 , Testing Accurancy 0.9282000064849854
# Iter 78 , Testing Accurancy 0.9284999966621399
# Iter 79 , Testing Accurancy 0.9290000200271606
# Iter 80 , Testing Accurancy 0.9282000064849854
# Iter 81 , Testing Accurancy 0.9280999898910522
# Iter 82 , Testing Accurancy 0.928600013256073
# Iter 83 , Testing Accurancy 0.928600013256073
# Iter 84 , Testing Accurancy 0.929099977016449
# Iter 85 , Testing Accurancy 0.9280999898910522
# Iter 86 , Testing Accurancy 0.9279999732971191
# Iter 87 , Testing Accurancy 0.928600013256073
# Iter 88 , Testing Accurancy 0.9276000261306763
# Iter 89 , Testing Accurancy 0.928600013256073
# Iter 90 , Testing Accurancy 0.9280999898910522
# Iter 91 , Testing Accurancy 0.9280999898910522
# Iter 92 , Testing Accurancy 0.9286999702453613
# Iter 93 , Testing Accurancy 0.928600013256073
# Iter 94 , Testing Accurancy 0.928600013256073
# Iter 95 , Testing Accurancy 0.9284999966621399
# Iter 96 , Testing Accurancy 0.9283999800682068
# Iter 97 , Testing Accurancy 0.9279999732971191
# Iter 98 , Testing Accurancy 0.9287999868392944
# Iter 99 , Testing Accurancy 0.9286999702453613
# Iter 100 , Testing Accurancy 0.9287999868392944
# Iter 101 , Testing Accurancy 0.9287999868392944
# Iter 102 , Testing Accurancy 0.9283000230789185
# Iter 103 , Testing Accurancy 0.9286999702453613
# Iter 104 , Testing Accurancy 0.9286999702453613
# Iter 105 , Testing Accurancy 0.9283000230789185
# Iter 106 , Testing Accurancy 0.9289000034332275
# Iter 107 , Testing Accurancy 0.9283000230789185
# Iter 108 , Testing Accurancy 0.9290000200271606
# Iter 109 , Testing Accurancy 0.929099977016449
# Iter 110 , Testing Accurancy 0.9286999702453613
# Iter 111 , Testing Accurancy 0.9283000230789185
# Iter 112 , Testing Accurancy 0.9286999702453613
# Iter 113 , Testing Accurancy 0.928600013256073
# Iter 114 , Testing Accurancy 0.9291999936103821
# Iter 115 , Testing Accurancy 0.9279000163078308
# Iter 116 , Testing Accurancy 0.9279000163078308
# Iter 117 , Testing Accurancy 0.9280999898910522
# Iter 118 , Testing Accurancy 0.9284999966621399
# Iter 119 , Testing Accurancy 0.9290000200271606
# Iter 120 , Testing Accurancy 0.9284999966621399
# Iter 121 , Testing Accurancy 0.9286999702453613
# Iter 122 , Testing Accurancy 0.9282000064849854
# Iter 123 , Testing Accurancy 0.9282000064849854
# Iter 124 , Testing Accurancy 0.9280999898910522
# Iter 125 , Testing Accurancy 0.9294999837875366
# Iter 126 , Testing Accurancy 0.9282000064849854
# Iter 127 , Testing Accurancy 0.9286999702453613
# Iter 128 , Testing Accurancy 0.9286999702453613
# Iter 129 , Testing Accurancy 0.9290000200271606
# Iter 130 , Testing Accurancy 0.9279000163078308
# Iter 131 , Testing Accurancy 0.9279000163078308
# Iter 132 , Testing Accurancy 0.9290000200271606
# Iter 133 , Testing Accurancy 0.9279999732971191
# Iter 134 , Testing Accurancy 0.9286999702453613
# Iter 135 , Testing Accurancy 0.9289000034332275
# Iter 136 , Testing Accurancy 0.9289000034332275
# Iter 137 , Testing Accurancy 0.9283000230789185
# Iter 138 , Testing Accurancy 0.929099977016449
# Iter 139 , Testing Accurancy 0.9287999868392944
# Iter 140 , Testing Accurancy 0.9286999702453613
# Iter 141 , Testing Accurancy 0.9284999966621399
# Iter 142 , Testing Accurancy 0.9284999966621399
# Iter 143 , Testing Accurancy 0.9287999868392944
# Iter 144 , Testing Accurancy 0.9291999936103821
# Iter 145 , Testing Accurancy 0.928600013256073
# Iter 146 , Testing Accurancy 0.9287999868392944
# Iter 147 , Testing Accurancy 0.9283000230789185
# Iter 148 , Testing Accurancy 0.929099977016449
# Iter 149 , Testing Accurancy 0.9290000200271606
# Iter 150 , Testing Accurancy 0.929099977016449
# Iter 151 , Testing Accurancy 0.9291999936103821
# Iter 152 , Testing Accurancy 0.9294000267982483
# Iter 153 , Testing Accurancy 0.9297000169754028
# Iter 154 , Testing Accurancy 0.9283000230789185
# Iter 155 , Testing Accurancy 0.9293000102043152
# Iter 156 , Testing Accurancy 0.9287999868392944
# Iter 157 , Testing Accurancy 0.9294000267982483
# Iter 158 , Testing Accurancy 0.9293000102043152
# Iter 159 , Testing Accurancy 0.9290000200271606
# Iter 160 , Testing Accurancy 0.9289000034332275
# Iter 161 , Testing Accurancy 0.9296000003814697
# Iter 162 , Testing Accurancy 0.9293000102043152
# Iter 163 , Testing Accurancy 0.9293000102043152
# Iter 164 , Testing Accurancy 0.9294000267982483
# Iter 165 , Testing Accurancy 0.9297000169754028
# Iter 166 , Testing Accurancy 0.929099977016449
# Iter 167 , Testing Accurancy 0.9294999837875366
# Iter 168 , Testing Accurancy 0.9297000169754028
# Iter 169 , Testing Accurancy 0.9297000169754028
# Iter 170 , Testing Accurancy 0.9293000102043152
# Iter 171 , Testing Accurancy 0.9293000102043152
# Iter 172 , Testing Accurancy 0.9294000267982483
# Iter 173 , Testing Accurancy 0.9290000200271606
# Iter 174 , Testing Accurancy 0.9294999837875366
# Iter 175 , Testing Accurancy 0.9294999837875366
# Iter 176 , Testing Accurancy 0.9296000003814697
# Iter 177 , Testing Accurancy 0.9290000200271606
# Iter 178 , Testing Accurancy 0.9297000169754028
# Iter 179 , Testing Accurancy 0.9287999868392944
# Iter 180 , Testing Accurancy 0.9289000034332275
# Iter 181 , Testing Accurancy 0.9290000200271606
# Iter 182 , Testing Accurancy 0.9298999905586243
# Iter 183 , Testing Accurancy 0.9300000071525574
# Iter 184 , Testing Accurancy 0.9297999739646912
# Iter 185 , Testing Accurancy 0.9293000102043152
# Iter 186 , Testing Accurancy 0.9294000267982483
# Iter 187 , Testing Accurancy 0.9287999868392944
# Iter 188 , Testing Accurancy 0.9297000169754028
# Iter 189 , Testing Accurancy 0.9297999739646912
# Iter 190 , Testing Accurancy 0.9297999739646912
# Iter 191 , Testing Accurancy 0.9297000169754028
# Iter 192 , Testing Accurancy 0.9294999837875366
# Iter 193 , Testing Accurancy 0.9294000267982483
# Iter 194 , Testing Accurancy 0.9287999868392944
# Iter 195 , Testing Accurancy 0.9297999739646912
# Iter 196 , Testing Accurancy 0.9301000237464905
# Iter 197 , Testing Accurancy 0.9297999739646912
# Iter 198 , Testing Accurancy 0.9291999936103821
# Iter 199 , Testing Accurancy 0.9297999739646912
# Iter 200 , Testing Accurancy 0.9296000003814697
